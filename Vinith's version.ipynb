# %%
import pandas as pd

Eversource = pd.read_csv('Eversource.csv')
Eversource.head()
# Out:
#        TOWN  ZIPCODE  Average Customer Duration ( Hours)  \
# 0  ABINGTON     6230                                  24
# 1    AMSTON     6231                                  20
# 2   ANDOVER     6232                                  24
# 3   ASHFORD     6278                                  21
# 4      AVON     6001                                  21
#
#    Total Duration Hours  # Events Affecting Town/Zipcode  Customers Served  \
# 0               31729.4                              128               104
# 1              166846.9                              222               840
# 2              234042.6                              299              1429
# 3              490057.4                              455              2204
# 4             1020814.8                              584              8756
#
#    Outages Per Customer Events/Customer Above Average IND  \
# 0                 1.231                      BelowAverage
# 1                 0.264                      BelowAverage
# 2                 0.209                      BelowAverage
# 3                 0.206                      BelowAverage
# 4                 0.067                      BelowAverage
#
#   Duration Above Average
# 0           BelowAverage
# 1           BelowAverage
# 2           BelowAverage
# 3           BelowAverage
# 4           BelowAverage

# %%
from geoid import acs

# %%
ct = pd.read_csv('ct_cbgs.csv')
ct.head()
# Out:
#    Unnamed: 0      GEOID10  Housing burden (percent)  Total population  \
# 0           0  90010101011                  0.224719            1058.0
# 1           1  90010101012                  0.224719             600.0
# 2           2  90010101013                  0.224719            1221.0
# 3           3  90010101014                  0.224719            1393.0
# 4           4  90010101021                  0.103586            1358.0
#
#    Median household income (% of state median household income)  \
# 0                                           2.370761
# 1                                           1.560464
# 2                                           3.187000
# 3                                           1.659222
# 4                                           3.187000
#
#    Current asthma among adults aged >=18 years  \
# 0                                          8.5
# 1                                          8.5
# 2                                          8.5
# 3                                          8.5
# 4                                          8.0
#
#    Coronary heart disease among adults aged >=18 years  \
# 0                                                6.7
# 1                                                6.7
# 2                                                6.7
# 3                                                6.7
# 4                                                5.0
#
#    Cancer (excluding skin cancer) among adults aged >=18 years  \
# 0                                                9.9
# 1                                                9.9
# 2                                                9.9
# 3                                                9.9
# 4                                                8.6
#
#    Current lack of health insurance among adults aged 18-64 years  \
# 0                                                5.9
# 1                                                5.9
# 2                                                5.9
# 3                                                5.9
# 4                                                4.5
#
#    Diagnosed diabetes among adults aged >=18 years  ...  \
# 0                                              8.6  ...
# 1                                              8.6  ...
# 2                                              8.6  ...
# 3                                              8.6  ...
# 4                                              7.0  ...
#
#    Score K (communities)  county   tract  bg  zcta5      cntyname    zipname  \
# 0                  False    9001  101.01   1   6831  Fairfield CT  GREENWICH
# 1                  False    9001  101.01   2   6831  Fairfield CT  GREENWICH
# 2                  False    9001  101.01   3   6831  Fairfield CT  GREENWICH
# 3                  False    9001  101.01   4   6831  Fairfield CT  GREENWICH
# 4                  False    9001  101.02   1   6830  Fairfield CT      BYRAM
#
#    pop2k  afact        cbgid
# 0    779  1.000  90010101011
# 1    785  1.000  90010101012
# 2   1494  1.000  90010101013
# 3   1603  1.000  90010101014
# 4    820  0.617  90010101021
#
# [5 rows x 183 columns]

# %%
ct = ct.drop(['Current asthma among adults aged >=18 years', 'Coronary heart disease among adults aged >=18 years', 'Cancer (excluding skin cancer) among adults aged >=18 years', 'Diagnosed diabetes among adults aged >=18 years', 'Physical health not good for >=14 days among adults aged >=18 years', ], axis = 1)

# %%
ct.head()
# Out:
#    Unnamed: 0      GEOID10  Housing burden (percent)  Total population  \
# 0           0  90010101011                  0.224719            1058.0
# 1           1  90010101012                  0.224719             600.0
# 2           2  90010101013                  0.224719            1221.0
# 3           3  90010101014                  0.224719            1393.0
# 4           4  90010101021                  0.103586            1358.0
#
#    Median household income (% of state median household income)  \
# 0                                           2.370761
# 1                                           1.560464
# 2                                           3.187000
# 3                                           1.659222
# 4                                           3.187000
#
#    Current lack of health insurance among adults aged 18-64 years  \
# 0                                                5.9
# 1                                                5.9
# 2                                                5.9
# 3                                                5.9
# 4                                                4.5
#
#    Percent of individuals < 100% Federal Poverty Line  \
# 0                                           0.072154
# 1                                           0.000000
# 2                                           0.050263
# 3                                           0.031603
# 4                                           0.014239
#
#    Percent of individuals < 150% Federal Poverty Line  \
# 0                                           0.237805
# 1                                           0.030837
# 2                                           0.051013
# 3                                           0.041761
# 4                                           0.014239
#
#    Percent of individuals < 200% Federal Poverty Line  \
# 0                                           0.293699
# 1                                           0.063142
# 2                                           0.051013
# 3                                           0.041761
# 4                                           0.069903
#
#    Area Median Income (State or metropolitan)  ...  Score K (communities)  \
# 0                                     95645.0  ...                  False
# 1                                     95645.0  ...                  False
# 2                                     95645.0  ...                  False
# 3                                     95645.0  ...                  False
# 4                                     95645.0  ...                  False
#
#    county   tract  bg  zcta5      cntyname    zipname  pop2k  afact  \
# 0    9001  101.01   1   6831  Fairfield CT  GREENWICH    779  1.000
# 1    9001  101.01   2   6831  Fairfield CT  GREENWICH    785  1.000
# 2    9001  101.01   3   6831  Fairfield CT  GREENWICH   1494  1.000
# 3    9001  101.01   4   6831  Fairfield CT  GREENWICH   1603  1.000
# 4    9001  101.02   1   6830  Fairfield CT      BYRAM    820  0.617
#
#          cbgid
# 0  90010101011
# 1  90010101012
# 2  90010101013
# 3  90010101014
# 4  90010101021
#
# [5 rows x 178 columns]

# %%
ct_refined = ct[['GEOID10','Median household income (% of state median household income)', 'Area Median Income (State or metropolitan)', 'zipname']].copy()
ct_refined.head()
# Out:
#        GEOID10  Median household income (% of state median household income)  \
# 0  90010101011                                           2.370761
# 1  90010101012                                           1.560464
# 2  90010101013                                           3.187000
# 3  90010101014                                           1.659222
# 4  90010101021                                           3.187000
#
#    Area Median Income (State or metropolitan)    zipname
# 0                                     95645.0  GREENWICH
# 1                                     95645.0  GREENWICH
# 2                                     95645.0  GREENWICH
# 3                                     95645.0  GREENWICH
# 4                                     95645.0      BYRAM

# %%
ct_merged = pd.read_csv('merged_data.csv')
ct_refined = ct_merged[['Median household income (% of state median household income)', 'Area Median Income (State or metropolitan)', 'zipname_y', 'ZIPCODE', 'Housing burden (percent)', 'Energy burden', 'Energy burden (percentile)', 'Individuals over 64 years old', 'Physical health not good for >=14 days among adults aged >=18 years', 'FEMA Risk Index Expected Annual Loss Score', 'Housing + Transportation Costs % Income for the Regional Typical Household (percentile)', 'Percent individuals age 25 or over with less than high school degree (percentile)', 'Persistent Poverty Census Tract', 'Percent of individuals < 200% Federal Poverty Line (percentile)', 'Life expectancy (years)']].copy()
ct_refined.head()
# Out:
#    Median household income (% of state median household income)  \
# 0                                           2.370761
# 1                                           1.560464
# 2                                           3.187000
# 3                                           1.659222
# 4                                           3.187000
#
#    Area Median Income (State or metropolitan)  zipname_y  ZIPCODE  \
# 0                                     95645.0  GREENWICH     6831
# 1                                     95645.0  GREENWICH     6831
# 2                                     95645.0  GREENWICH     6831
# 3                                     95645.0  GREENWICH     6831
# 4                                     95645.0  GREENWICH     6831
#
#    Housing burden (percent)  Energy burden  Energy burden (percentile)  \
# 0                  0.224719           0.02                    0.199716
# 1                  0.224719           0.02                    0.199716
# 2                  0.224719           0.02                    0.199716
# 3                  0.224719           0.02                    0.199716
# 4                  0.103586           0.02                    0.199716
#
#    Individuals over 64 years old  \
# 0                       0.275992
# 1                       0.175000
# 2                       0.200655
# 3                       0.323044
# 4                       0.192931
#
#    Physical health not good for >=14 days among adults aged >=18 years  \
# 0                                               10.4
# 1                                               10.4
# 2                                               10.4
# 3                                               10.4
# 4                                                8.1
#
#    FEMA Risk Index Expected Annual Loss Score  \
# 0                                   17.342298
# 1                                   17.342298
# 2                                   17.342298
# 3                                   17.342298
# 4                                   15.736806
#
#    Housing + Transportation Costs % Income for the Regional Typical Household (percentile)  \
# 0                                           0.936984
# 1                                           0.930205
# 2                                           0.856143
# 3                                           0.805288
# 4                                           0.943163
#
#    Percent individuals age 25 or over with less than high school degree (percentile)  \
# 0                                           0.373408
# 1                                           0.278633
# 2                                           0.141046
# 3                                           0.349333
# 4                                           0.130473
#
#   Persistent Poverty Census Tract  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    Percent of individuals < 200% Federal Poverty Line (percentile)  \
# 0                                           0.495065
# 1                                           0.072679
# 2                                           0.053861
# 3                                           0.040672
# 4                                           0.083604
#
#    Life expectancy (years)
# 0                     81.0
# 1                     81.0
# 2                     81.0
# 3                     81.0
# 4                     85.5

# %%
ct_refined = ct_refined.groupby('ZIPCODE').mean()

# %%
Final_data = pd.merge(ct_refined, Eversource, on='ZIPCODE')

# %%
print(Final_data)
# Out:
#      ZIPCODE  Median household income (% of state median household income)  \
# 0       6001                                           1.826267
# 1       6002                                           1.015136
# 2       6010                                           0.900913
# 3       6013                                                NaN
# 4       6016                                           1.183614
# ..       ...                                                ...
# 259     6902                                           1.312952
# 260     6903                                           2.461202
# 261     6905                                           1.631253
# 262     6906                                           1.224287
# 263     6907                                           1.521947
#
#      Area Median Income (State or metropolitan)  Housing burden (percent)  \
# 0                                       77769.0                  0.157547
# 1                                       77769.0                  0.298781
# 2                                       77769.0                  0.291703
# 3                                           NaN                       NaN
# 4                                       77769.0                  0.236299
# ..                                          ...                       ...
# 259                                     95645.0                  0.340288
# 260                                     95645.0                  0.148039
# 261                                     95645.0                  0.230479
# 262                                     95645.0                  0.391075
# 263                                     95645.0                  0.283370
#
#      Energy burden  Energy burden (percentile)  Individuals over 64 years old  \
# 0         0.022000                    0.252437                       0.196476
# 1         0.034545                    0.570185                       0.215335
# 2         0.041250                    0.692750                       0.152961
# 3              NaN                         NaN                            NaN
# 4         0.034000                    0.557362                       0.183749
# ..             ...                         ...                            ...
# 259       0.025156                    0.331629                       0.133888
# 260       0.020000                    0.199716                       0.205858
# 261       0.020571                    0.214779                       0.144297
# 262       0.022500                    0.265617                       0.140883
# 263       0.023333                    0.287584                       0.127922
#
#      Physical health not good for >=14 days among adults aged >=18 years  \
# 0                                             8.300000
# 1                                            11.645455
# 2                                            12.218750
# 3                                                  NaN
# 4                                            10.380000
# ..                                                 ...
# 259                                          10.123438
# 260                                           8.400000
# 261                                           8.580000
# 262                                          10.331250
# 263                                           9.700000
#
#      FEMA Risk Index Expected Annual Loss Score  \
# 0                                     18.623516
# 1                                     20.480549
# 2                                     24.535966
# 3                                           NaN
# 4                                     13.538465
# ..                                          ...
# 259                                   36.437038
# 260                                   23.650915
# 261                                   36.601474
# 262                                   37.136625
# 263                                   33.644110
#
#      Housing + Transportation Costs % Income for the Regional Typical Household (percentile)  \
# 0                                             0.719441
# 1                                             0.314730
# 2                                             0.260891
# 3                                                  NaN
# 4                                             0.487276
# ..                                                 ...
# 259                                           0.350692
# 260                                           0.854561
# 261                                           0.518493
# 262                                           0.294533
# 263                                           0.574272
#
#      ...  Percent of individuals < 200% Federal Poverty Line (percentile)  \
# 0    ...                                           0.128791
# 1    ...                                           0.276419
# 2    ...                                           0.408359
# 3    ...                                                NaN
# 4    ...                                           0.191957
# ..   ...                                                ...
# 259  ...                                           0.344369
# 260  ...                                           0.057091
# 261  ...                                           0.167506
# 262  ...                                           0.376000
# 263  ...                                           0.191010
#
#      Life expectancy (years)         TOWN Average Customer Duration ( Hours)  \
# 0                  82.860000         AVON                                 21
# 1                  79.818182   BLOOMFIELD                                 18
# 2                  79.371875      BRISTOL                                 23
# 3                        NaN   BURLINGTON                                 24
# 4                  79.540000  BROAD BROOK                                 37
# ..                       ...          ...                                ...
# 259                81.518750     STAMFORD                                 44
# 260                85.200000     STAMFORD                                 46
# 261                82.620000     STAMFORD                                 32
# 262                81.268750     STAMFORD                                 29
# 263                81.700000     STAMFORD                                 32
#
#      Total Duration Hours  # Events Affecting Town/Zipcode  Customers Served  \
# 0               1020814.8                              584              8756
# 1                579255.5                              577             10708
# 2               1407252.9                              660             29940
# 3                408591.7                              248              3921
# 4                307871.1                              163              3042
# ..                    ...                              ...               ...
# 259             1320958.7                              788             30931
# 260             1504628.2                             1480              5472
# 261              579299.8                              485              9598
# 262              247825.0                              156              4346
# 263              246211.5                              194              4279
#
#      Outages Per Customer  Events/Customer Above Average IND  \
# 0                   0.067                       BelowAverage
# 1                   0.054                       BelowAverage
# 2                   0.022                       BelowAverage
# 3                   0.063                       BelowAverage
# 4                   0.054                       BelowAverage
# ..                    ...                                ...
# 259                 0.025                       BelowAverage
# 260                 0.270                       BelowAverage
# 261                 0.051                       BelowAverage
# 262                 0.036                       BelowAverage
# 263                 0.045                       BelowAverage
#
#     Duration Above Average
# 0             BelowAverage
# 1             BelowAverage
# 2             BelowAverage
# 3             BelowAverage
# 4             BelowAverage
# ..                     ...
# 259           BelowAverage
# 260           BelowAverage
# 261           BelowAverage
# 262           BelowAverage
# 263           BelowAverage
#
# [264 rows x 21 columns]

# %%
Final_data.to_csv('final_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = Final_data.corr()
plt.figure(figsize=(14,8))
plt.title('Overall Correlation', fontsize=20)
sns.heatmap(corr,annot=False,cmap='RdYlBu',linewidths=0.2,annot_kws={'size':20})
plt.show()
